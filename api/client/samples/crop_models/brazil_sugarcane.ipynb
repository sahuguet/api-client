# %% [markdown]
# # Brazil sugarcane crop model using Gro API
# In this notebook, we walk through the process of building a simple "crop model" using data in Gro. The accompanying Gro web app display for [Brazil Sugarcane](https://app.gro-intelligence.com/displays/23713) provides an overview of the data series we will use. The crop model we will create is a very basic  model that uses crop-production-weighted NDVI to forecast  yield.
#
# ## Preliminary
# First we construct a `CropModel` object. We also save the entity ids for the `item` [sugarcane](https://app.gro-intelligence.com/dictionary/items/538) and for the `region` [Brazil](https://app.gro-intelligence.com/dictionary/regions/1029).  We will use these throughout the notebook to simplify the retrieval, storage and manipulation of data.

# %%
import os
from api.client.crop_model import CropModel

model = CropModel('api.gro-intelligence.com', os.environ['GROAPI_TOKEN'])
country_id = model.search_for_entity('regions', "brazil")
crop_id =  model.search_for_entity('items', "sugarcane")

# %% [markdown]
# ##  Historical yields
# To get data series for national level sugarcane yield for Brazil, we set the entities (item, metric and region), and get the available data series.  The <em>source</em> for Brazil sugarcane yields is [FAO](https://app.gro-intelligence.com/dictionary/sources/2).

# %%
yield_entities = {}
yield_entities['item_id']  = crop_id
yield_entities['region_id'] = country_id
yield_entities['metric_id'] = model.search_for_entity('metrics', "yield mass/area")
data_series_list = model.get_data_series(**yield_entities)
print("There are {} data series for {}.".format(len(data_series_list), yield_entities))
for data_series in data_series_list:
    print("source_id {}: {} to {}".format(
        data_series['source_id'], data_series['start_date'], data_series['end_date']))
    model.add_single_data_series(data_series)
# Out:
# Added {u'end_date': u'2017-12-31T00:00:00.000Z', u'source_name': u'FAO', u'region_id': 1029, u'region_name': u'Brazil', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 2, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Yield (mass/area)', u'start_date': u'1961-01-01T00:00:00.000Z', u'metric_id': 170037}
# There are 1 data series for {'item_id': 538, 'region_id': 1029, 'metric_id': 170037}.
# source_id 2: 1961-01-01T00:00:00.000Z to 2017-12-31T00:00:00.000Z

# %%
# %matplotlib inline
import pandas
import matplotlib.pyplot as plt

df = model.get_df()
yield_df = df.loc[(df.metric_id == yield_entities['metric_id']) & \
                  (df.region_id == yield_entities['region_id'])]
yield_df.end_date = pandas.to_datetime(yield_df.end_date)
yield_df.set_index('end_date')
fig, axes = plt.subplots(1, 1)
yield_df.plot(x='end_date', y='value', ax=axes)
plt.ylabel("Yield (t/ha)")
plt.show()
# Out:
# /Library/Python/2.7/site-packages/pandas/core/arrays/datetimes.py:1172: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   "will drop timezone information.", UserWarning)

# %% [markdown]
# ## Production "weight" of provinces
# We compute the "weight" of each province, based on the full history of production quantity per province. The weights are normalized to add up to 1.0. A weight of 0.2 means we expect that province to account for 20% of the country's production.

# %%
provinces = model.get_provinces("brazil")
weights = model.compute_weights("sugarcane", "Production Quantity mass", provinces)
max_weight = max(filter(lambda x: x >0, weights))
print ('Total weight: {}'.format(sum(filter(lambda x: x >0, weights))))
print ('Maximum weight: {}'.format(max_weight))
# Out:
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10405, u'region_name': u'Para\xedba', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10416, u'region_name': u'Maranh\xe3o', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10427, u'region_name': u'Sergipe', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10421, u'region_name': u'Piau\xed', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10417, u'region_name': u'Mato Grosso do Sul', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10422, u'region_name': u'Rio de Janeiro', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10423, u'region_name': u'Rio Grande do Norte', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10419, u'region_name': u'Par\xe1', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10420, u'region_name': u'Pernambuco', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10410, u'region_name': u'Alagoas', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10414, u'region_name': u'Esp\xedrito Santo', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10409, u'region_name': u'Acre', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10425, u'region_name': u'Rond\xf4nia', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10418, u'region_name': u'Mato Grosso', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10415, u'region_name': u'Goi\xe1s', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10403, u'region_name': u'Cear\xe1', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10428, u'region_name': u'Tocantins', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10407, u'region_name': u'Santa Catarina', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10424, u'region_name': u'Rio Grande do Sul', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10402, u'region_name': u'Bahia', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10404, u'region_name': u'Minas Gerais', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10408, u'region_name': u'S\xe3o Paulo', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10406, u'region_name': u'Paran\xe1', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10412, u'region_name': u'Amazonas', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# /Library/Python/2.7/site-packages/pandas/core/reshape/merge.py:938: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   'representation', UserWarning)
# Total weight: 1.0
# Maximum weight: 0.592114588285

# %%
import geopandas
from shapely.geometry import shape

gdf = geopandas.GeoDataFrame([{
       'region_id': province['id'], 
       'geometry': shape(model.get_geojson(province['id'])['geometries'][0]),
       'production_weight': weight if weight > 0 else 0
    } for (province, weight) in zip(provinces, weights)])
gdf.set_index('region_id')

fig, axes = plt.subplots(1, 1)
gdf.plot(column='production_weight', 
         cmap='Blues', ax=axes, vmin=0, vmax=max_weight, legend=True)
axes.set_title('Crop Production Weight')
axes.xaxis.set_visible(False)
axes.yaxis.set_visible(False)
plt.show()

# %% [markdown]
# ## NDVI, province level
# The main signal we will use to model crop yields is [NDVI](https://app.gro-intelligence.com/dictionary/items/321), which represents vegetation biomass per pixel, and thus is a good physical proxy for yield (production mass per unit of area).
#
# First we load the historical data for province level NDVI.  Here, there  are actually two data series for each region, one with `8-day` and one with `16-day` periods. We choose to use the series with 8-day (frequency_id = 3).

# %%
entities = {}
entities['item_id'] =  model.search_for_entity('items', "Vegetation NDVI")
entities['metric_id'] = model.search_for_entity('metrics', "Vegetation Indices index")
entities['frequency_id'] = 3

for province in provinces:
    entities['region_id'] = province['id']
    for data_series in model.get_data_series(**entities):
        model.add_single_data_series(data_series)
# Out:
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10405, u'region_name': u'Para\xedba', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-26T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10416, u'region_name': u'Maranh\xe3o', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10427, u'region_name': u'Sergipe', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-26T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10411, u'region_name': u'Amap\xe1', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10421, u'region_name': u'Piau\xed', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-26T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10413, u'region_name': u'Distrito Federal', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10417, u'region_name': u'Mato Grosso do Sul', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10422, u'region_name': u'Rio de Janeiro', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-26T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10423, u'region_name': u'Rio Grande do Norte', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-26T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10419, u'region_name': u'Par\xe1', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10426, u'region_name': u'Roraima', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10420, u'region_name': u'Pernambuco', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-26T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10410, u'region_name': u'Alagoas', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-26T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10414, u'region_name': u'Esp\xedrito Santo', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-26T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10409, u'region_name': u'Acre', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10425, u'region_name': u'Rond\xf4nia', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10418, u'region_name': u'Mato Grosso', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10415, u'region_name': u'Goi\xe1s', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10403, u'region_name': u'Cear\xe1', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-26T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10428, u'region_name': u'Tocantins', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10407, u'region_name': u'Santa Catarina', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10424, u'region_name': u'Rio Grande do Sul', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10402, u'region_name': u'Bahia', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-26T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10404, u'region_name': u'Minas Gerais', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10408, u'region_name': u'S\xe3o Paulo', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10406, u'region_name': u'Paran\xe1', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10412, u'region_name': u'Amazonas', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}

# %% [markdown]
# ## NDVI crop-weighted, province level
# NDVI represents the biomass  of <em>all</em> vegetation, not just sugarcane. To make it a more accurate signal, we compute the crop-weighted version of NDVI.

# %%
sugar_ndvi_df = model.compute_crop_weighted_series(
    'sugarcane', 'Production Quantity mass',
    'Vegetation NDVI', 'Vegetation Indices index',
    provinces)
# Out:
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10405, u'region_name': u'Para\xedba', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10416, u'region_name': u'Maranh\xe3o', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10427, u'region_name': u'Sergipe', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10421, u'region_name': u'Piau\xed', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10417, u'region_name': u'Mato Grosso do Sul', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10422, u'region_name': u'Rio de Janeiro', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10423, u'region_name': u'Rio Grande do Norte', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10419, u'region_name': u'Par\xe1', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10420, u'region_name': u'Pernambuco', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10410, u'region_name': u'Alagoas', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10414, u'region_name': u'Esp\xedrito Santo', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10409, u'region_name': u'Acre', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10425, u'region_name': u'Rond\xf4nia', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10418, u'region_name': u'Mato Grosso', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10415, u'region_name': u'Goi\xe1s', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10403, u'region_name': u'Cear\xe1', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10428, u'region_name': u'Tocantins', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10407, u'region_name': u'Santa Catarina', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10424, u'region_name': u'Rio Grande do Sul', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10402, u'region_name': u'Bahia', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10404, u'region_name': u'Minas Gerais', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10408, u'region_name': u'S\xe3o Paulo', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10406, u'region_name': u'Paran\xe1', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2018-03-31T00:00:00.000Z', u'source_name': u'UNICA', u'region_id': 10412, u'region_name': u'Amazonas', u'item_name': u'Sugarcane', u'partner_region_name': u'World', u'frequency_id': 9, u'source_id': 47, u'partner_region_id': 0, u'item_id': 538, u'metric_name': u'Production Quantity (mass)', u'start_date': u'1980-04-01T00:00:00.000Z', u'metric_id': 860032}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10405, u'region_name': u'Para\xedba', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-26T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10416, u'region_name': u'Maranh\xe3o', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10427, u'region_name': u'Sergipe', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-26T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10411, u'region_name': u'Amap\xe1', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10421, u'region_name': u'Piau\xed', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-26T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10413, u'region_name': u'Distrito Federal', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10417, u'region_name': u'Mato Grosso do Sul', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10422, u'region_name': u'Rio de Janeiro', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-26T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10423, u'region_name': u'Rio Grande do Norte', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-26T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10419, u'region_name': u'Par\xe1', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10426, u'region_name': u'Roraima', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10420, u'region_name': u'Pernambuco', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-26T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10410, u'region_name': u'Alagoas', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-26T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10414, u'region_name': u'Esp\xedrito Santo', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-26T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10409, u'region_name': u'Acre', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10425, u'region_name': u'Rond\xf4nia', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10418, u'region_name': u'Mato Grosso', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10415, u'region_name': u'Goi\xe1s', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10403, u'region_name': u'Cear\xe1', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-26T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10428, u'region_name': u'Tocantins', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10407, u'region_name': u'Santa Catarina', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10424, u'region_name': u'Rio Grande do Sul', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10402, u'region_name': u'Bahia', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-26T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10404, u'region_name': u'Minas Gerais', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10408, u'region_name': u'S\xe3o Paulo', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10406, u'region_name': u'Paran\xe1', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 10412, u'region_name': u'Amazonas', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}
# Computing Vegetation NDVI_Vegetation Indices index_Paraíba x 0.000141125358065
# Computing Vegetation NDVI_Vegetation Indices index_Maranhão x 3.6648639997e-05
# Computing Vegetation NDVI_Vegetation Indices index_Sergipe x 4.54617020012e-05
# Computing Vegetation NDVI_Vegetation Indices index_Amapá x nan
# Computing Vegetation NDVI_Vegetation Indices index_Piauí x 1.44144224537e-05
# Computing Vegetation NDVI_Vegetation Indices index_Distrito Federal x nan
# Computing Vegetation NDVI_Vegetation Indices index_Mato Grosso do Sul x 0.0772434055989
# Computing Vegetation NDVI_Vegetation Indices index_Rio de Janeiro x 0.00235131629839
# Computing Vegetation NDVI_Vegetation Indices index_Rio Grande do Norte x 7.41908046243e-05
# Computing Vegetation NDVI_Vegetation Indices index_Pará x 1.20056462877e-05
# Computing Vegetation NDVI_Vegetation Indices index_Roraima x nan
# Computing Vegetation NDVI_Vegetation Indices index_Pernambuco x 0.000533793276481
# Computing Vegetation NDVI_Vegetation Indices index_Alagoas x 0.000693761614423
# Computing Vegetation NDVI_Vegetation Indices index_Espírito Santo x 0.00510156349946
# Computing Vegetation NDVI_Vegetation Indices index_Acre x 3.29149538212e-07
# Computing Vegetation NDVI_Vegetation Indices index_Rondônia x 1.33155949549e-06
# Computing Vegetation NDVI_Vegetation Indices index_Mato Grosso x 0.0286472491175
# Computing Vegetation NDVI_Vegetation Indices index_Goiás x 0.117097929682
# Computing Vegetation NDVI_Vegetation Indices index_Ceará x 8.49554906581e-06
# Computing Vegetation NDVI_Vegetation Indices index_Tocantins x 1.3449415853e-05
# Computing Vegetation NDVI_Vegetation Indices index_Santa Catarina x 4.72113479051e-06
# Computing Vegetation NDVI_Vegetation Indices index_Rio Grande do Sul x 0.00011374859458
# Computing Vegetation NDVI_Vegetation Indices index_Bahia x 6.30537473958e-05
# Computing Vegetation NDVI_Vegetation Indices index_Minas Gerais x 0.103884724338
# Computing Vegetation NDVI_Vegetation Indices index_São Paulo x 0.592114588285
# Computing Vegetation NDVI_Vegetation Indices index_Paraná x 0.07179881176
# Computing Vegetation NDVI_Vegetation Indices index_Amazonas x 3.88080604523e-06

# %% [markdown]
# Now let's look at NDVI by province, on a particular date. First, we select NDVI for all provinces from the model's dataframe, and join it with the geopandas dataframe that has the provinces geometry.   Second, we select the crop weighted NDVI for all provinces from the `sugar_ndvi_df` dataframe and do the same.

# %%
EVAL_DATE = u'2019-02-25T00:00:00.000Z'
df = model.get_df()
ndvi_df = df.loc[(df.metric_id == entities['metric_id']) & \
                 (df.end_date == EVAL_DATE),:]
gdf1 = gdf.join(ndvi_df.set_index('region_id'), on='region_id')

cwndvi_df = sugar_ndvi_df.loc[(sugar_ndvi_df.metric_id == entities['metric_id']) & \
                            (sugar_ndvi_df.end_date == EVAL_DATE), :]
gdf2 = gdf.join(cwndvi_df.set_index('region_id'), on='region_id')

fig, axes = plt.subplots(1, 2)
gdf1.plot(column='value', 
          cmap='Greens', ax=axes[0], vmin=0.0, vmax=1.0)
axes[0].set_title('NDVI')
axes[0].xaxis.set_visible(False)
axes[0].yaxis.set_visible(False)
gdf2.plot(column='value', 
          cmap='Greens', ax=axes[1], vmin=0.0, vmax=max_weight)
axes[1].set_title('Crop-weighted NDVI')
axes[1].xaxis.set_visible(False)
axes[1].yaxis.set_visible(False)
plt.show()
# Out:
# /Library/Python/2.7/site-packages/matplotlib/colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %% [markdown]
# ## NDVI, country level
# NDVI is available as a data series at all region levels, so we just add it to the model at the country level.

# %%
entities['region_id'] = country_id
for data_series in model.get_data_series(**entities):
    model.add_single_data_series(data_series)
df = model.get_df()
df.end_date = pandas.to_datetime(df.end_date, utc=True)
country_ndvi_df = df.loc[(df.metric_id == entities['metric_id']) & \
                         (df.region_id == entities['region_id'])]
# Out:
# Added {u'end_date': u'2019-05-08T00:00:00.000Z', u'source_name': u'GIMMS MODIS NDVI', u'region_id': 1029, u'region_name': u'Brazil', u'item_name': u'Vegetation (NDVI)', u'partner_region_name': u'World', u'frequency_id': 3, u'source_id': 3, u'partner_region_id': 0, u'item_id': 321, u'metric_name': u'Vegetation Indices', u'start_date': u'2000-02-18T00:00:00.000Z', u'metric_id': 70029}

# %% [markdown]
# For crop weighted NDVI, we need to aggregate it up from provinces. Since the crop-weighted NDVI series was built with weights normalized to 1.0, the sum of province level values is the national level value, for each date.

# %%
sugar_ndvi_df.end_date = pandas.to_datetime(sugar_ndvi_df.end_date, utc=True)
sugar_ndvi_df.set_index('end_date')
country_ndvi_df.set_index('end_date')

country_ndvi_df = country_ndvi_df.merge(pandas.DataFrame([{
    'end_date': end_date,
    'crop_weighted_value': value
} for (end_date, value) in zip(sugar_ndvi_df.end_date, 
                               sugar_ndvi_df.groupby(['end_date']).sum().value)]))

fig, axes = plt.subplots(1, 1)
country_ndvi_df.plot(x='end_date', y=['crop_weighted_value', 'value'], ax=axes)
plt.ylabel('NDVI')
plt.show()

# %% [markdown]
# ## Relationship between  yield and crop-weighted NDVI
# On any day during the season, we can look at crop weighted NDVI as a rough aproximation of the amount of sugarcane being grown per unit of area. Let's see if this would work as a predictor of the final yield of the crop for the current year. For this example, we pick February 25th of each year, which, as we can see from the crop calendar for this crop on our [display](https://app.gro-intelligence.com/displays/23713), is the end of the growth period, and just before harvesting starts.  This date is late enough in the season (end of growth) that the weighted NDVI should represent the final amount of the crop that will be produced, but it is early enough (before harvest) for the forecast to be useful.  Let's look at a scatter plot of historical values of  crop weighted NDVI on Feb 25 and final yields for the same year.

# %%
PREDICTION_DATE_MONTH = 2
PREDICTION_DATE_DAY = 25
tmp_df = country_ndvi_df.loc[(country_ndvi_df.metric_id == entities['metric_id']) & \
                             (country_ndvi_df.region_id == country_id) & \
                             (country_ndvi_df.end_date.map(lambda x: x.month) == PREDICTION_DATE_MONTH) &\
                             (country_ndvi_df.end_date.map(lambda x: x.day) == PREDICTION_DATE_DAY),:]
ym_df = pandas.DataFrame([{'year': end_date.year, 'yield': value}
                          for (end_date, value) in zip(yield_df.end_date, 
                                                   yield_df.value)])
cw_df = pandas.DataFrame([{'year': end_date.year, 'crop_weighted_ndvi': value}
                          for (end_date, value) in zip(tmp_df.end_date,
                                                       tmp_df.crop_weighted_value)])
ym_df = ym_df.merge(cw_df)
ym_df.plot.scatter(x='crop_weighted_ndvi', y = 'yield')
plt.show()

# %% [markdown]
# Indeed there seems to be a relationship between these two series, which means weighted NDVI on Feb 25 can be a reasonable predictor of final yield.
#
# ## Linear model
# An obvious next step is to do a linear regression, where we model `y = a * x + b` where x is the crop weighted NDVI.

# %%
from sklearn import linear_model

lm = linear_model.LinearRegression()
X = ym_df.loc[:,['crop_weighted_ndvi']]
lm.fit(X, ym_df['yield'])
lm_df =pandas.DataFrame([{'year': year, 'lm_yield': value}
                         for (year, value) in zip(ym_df.year, lm.predict(X))])
plt.scatter(ym_df['yield'], (lm_df['lm_yield']))
plt.xlabel("Actual yield")
plt.ylabel("Predicted yield (t/ha)")
plt.plot([min(ym_df['yield']), max(ym_df['yield'])], 
         [min(ym_df['yield']), max(ym_df['yield'])], color='red')
plt.show()

# %% [markdown]
# That is not a great fit, especially at higher yields, which is not surprising as we're using crop weights based on production rather than planted area.  Ideally to get the national yield, we would weight regional NDVI by  area.  Since production equals area multiplied by yield,  weighting by production instead of area will tend to over-wheight the high yield regions. Thus the model will be less accurate in years when the difference between regions is relatively large.
#
# ##  Quadratic+trend model
# A polynomial of degree 2 should help us capture this second order effect, and provide a better fit. So we try to fit  `y = a * x^2 + b * x + c` where x is the  crop weighted NDVI. Further, as there appears to be a longer term trend of improvement in yields, we add the year as another dependent variable to capture the long term trend. So the model becomes `y = a * x^2 + b * x + c + d * t`, where t is time (year).

# %%
X2 = pandas.DataFrame(X.crop_weighted_ndvi.map(lambda x: x*x))
X2.rename(columns={'crop_weighted_ndvi': 'crop_weighted_ndvi2'}, inplace=True)
X2 = pandas.DataFrame([X2.crop_weighted_ndvi2, X.crop_weighted_ndvi, ym_df.year]).transpose()
qm = linear_model.LinearRegression()
qm.fit(X2, ym_df['yield'])
qm_df =pandas.DataFrame([{'year': year, 'qm_yield': value}
                         for (year, value) in zip(ym_df.year, qm.predict(X2))])
plt.scatter(ym_df['yield'], (qm_df['qm_yield']))
plt.plot([min(ym_df['yield']), max(ym_df['yield'])], 
         [min(ym_df['yield']), max(ym_df['yield'])], color='red')
plt.xlabel("Actual yield (t/ha)")
plt.ylabel("Predicted yield (t/ha)")
plt.show()

# %% [markdown]
# ## Results
# The second model seems to provide a better looking fit. Looking at the standard regression statistics to confirm that:

# %%
from sklearn.metrics import mean_squared_error, r2_score
for reg in [lm.predict(X), qm.predict(X2)]:
    print mean_squared_error(ym_df['yield'], reg), r2_score(ym_df['yield'], reg)
# Out:
# 8.846595837341443 0.009189210429679795
# 8.32479448214395 0.0676304936360188

# %% [markdown]
# Indeed the quadratic+trend model
# - has a root-mean-square error of less than 0.02 t/ha i.e. less than 1%
# - explains about 77% of the variance in yields
#
# To get more perspective, let's see how well the models' fit reality as a function of time. As we can see in the following figure, the quadratic model does indeed outperform the linear model, especially in the high yield years.

# %%
backtest_df = ym_df.merge(lm_df).merge(qm_df)
backtest_df.year = pandas.to_datetime(backtest_df.year, format='%Y')
fig, axes = plt.subplots(1, 1)
backtest_df.plot(x='year', y = ['yield', 'lm_yield', 'qm_yield'], ax=axes)
plt.show()

# %% [markdown]
# ## Conclusion
# A full blown model requires a lot more signals. For example, in a [Gro Yield Model](https://app.gro-intelligence.com/dictionary/sources/32) data series for sugarcane in Brazil we would consider:
#
# - [evapotranspiration](https://app.gro-intelligence.com/dictionary/items/4395) as an additional input
# - district level historical yields from [CONAB](https://app.gro-intelligence.com/dictionary/sources/73) instead of only national level as above, and
# - [pixel-level crop masks](https://github.com/gro-intelligence/api-client/wiki/Gro-crop-masks) to weight the NDVI, instead of the coarser province level production weights.
#
# But this extremely simple crop model shows that a quick but reasonable fit (1% in-sample error-rate) can be achieved just using historical yields, production quantity, and NDVI.
#
# ##  Related links
# - Gro web app [display](https://app.gro-intelligence.com/displays/23713) accompanying this example
# - Sugarcane kit section of the [user manual](https://app.gro-intelligence.com/docs/user-manual#weather-data-soybean)
# - Gro Yield Model [web page and papers](https://gro-intelligence.com/yield-model/)
